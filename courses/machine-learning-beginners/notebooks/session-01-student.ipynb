# %% [markdown]
# # Session 1 — What Is Machine Learning?
#
# **Learning Objectives**
# - Confirm your Python + Jupyter + pandas + scikit-learn environment works
# - See a real dataset loaded as a pandas DataFrame for the first time

# %% [markdown]
# ## Environment Setup
#
# Before running the cells below, install the required packages (skip if using a pre-configured lab machine):
#
# ```bash
# pip install pandas scikit-learn jupyter
# ```

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from sklearn.datasets import load_iris

# %% [markdown]
# ## Instructor Demonstration
#
# The cell below loads the classic `iris` dataset (150 flowers, 4 measurements each) and shows it as a pandas DataFrame — the format we'll use for the rest of the course.

# %%
data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)
print("Dataset shape:", df.shape)
df.head(3)

# %% [markdown]
# ## Guided Exercise — Smoke Test
#
# Confirm the printed shape above is `(150, 4)` and that 3 rows are displayed. If you saw an error instead, see the Hints in `exercises/session-01-exercise.md` before continuing.

# %% [markdown]
# ## TODO
#
# Complete the cell below to print the **column names** of `df` (hint: DataFrames have a `.columns` attribute).

# %%
# TODO: print the column names of df
raise NotImplementedError("Print df.columns here")

# %% [markdown]
# ## Practice Task
#
# Using `df.describe()`, find the minimum and maximum `petal length (cm)` in the dataset. Write your answer as a comment in the cell below.

# %%
# Practice: use df.describe() to find min/max petal length (cm)
# Your answer (as a comment): min = ____, max = ____

# %% [markdown]
# ## Challenge Task (optional)
#
# Print `data.target_names` and `pd.Series(data.target).value_counts()` to see the three species this dataset contains and how many examples of each there are. We'll use this again in Session 3.

# %%
# Challenge (optional)

# %% [markdown]
# ## Reflection Questions
#
# 1. What's the difference between the DataFrame `df` and the original `data` object returned by `load_iris()`?
# 2. Why might a machine learning course start with loading data before writing any model code?
